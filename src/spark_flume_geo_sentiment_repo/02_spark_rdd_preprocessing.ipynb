# %% [markdown]
# # Spark RDD Preprocessing

# %%
# Spark RDD Preprocessingfrom pyspark.sql import SparkSessionimport respark = SparkSession.builder.appName("GeoSentiment").getOrCreate()sc = spark.sparkContextdef preprocess(text):    text = text.lower()    text = re.sub(r'[^a-zA-Z ]', '', text)    return textsample = ["AI is GREAT!!!", "Python for ML"]rdd = sc.parallelize(sample)clean_rdd = rdd.map(preprocess)print(clean_rdd.collect())# Technology ID mappingtech_map = {"Hadoop":0, "AI":1, "ML":2, "CC":3, "Python":4}print(tech_map)
