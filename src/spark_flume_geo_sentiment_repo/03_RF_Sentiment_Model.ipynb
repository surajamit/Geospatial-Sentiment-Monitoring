# %% [markdown]
# # Feature Extraction and Random Forest Classifier
# RF parameters: 200 trees, max depth 20.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report


rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=20,
    random_state=42
)

rf.fit(X, y)
y_pred = rf.predict(X)

print(classification_report(y, y_pred))
