# %% [markdown]
# # Spark RDD Processing Pipeline
# Implements real-time processing using Spark Streaming with 5-second micro-batches.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder     .appName("FUSION-SPARK-GEO-SENTIMENT")     .getOrCreate()

sc = spark.sparkContext
print("Spark session initialized")

# %%
rdd = sc.parallelize(["AI is booming", "Python is powerful", "Hadoop ecosystem"])

def preprocess(x_i):
    return x_i.lower().strip()

processed_rdd = rdd.map(preprocess)
print(processed_rdd.collect())
