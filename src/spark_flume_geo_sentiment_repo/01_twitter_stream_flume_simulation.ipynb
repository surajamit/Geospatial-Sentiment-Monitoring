# %% [markdown]
# # Twitter Stream via Flume

# %%
# Twitter Streaming Simulation with FlumeAPI_KEY = "YOUR_API_KEY"API_SECRET = "YOUR_API_SECRET"ACCESS_TOKEN = "YOUR_ACCESS_TOKEN"ACCESS_TOKEN_SECRET = "YOUR_ACCESS_TOKEN_SECRET"import timeimport randomdef simulate_tweet_stream(rate_per_sec=1500, duration_sec=5):    tweets = []    for _ in range(rate_per_sec * duration_sec):        tweets.append({            "text": "AI is transforming analytics",            "city": random.choice(["Chennai","Bengaluru","Mumbai","Delhi"])        })    return tweetstweets = simulate_tweet_stream()print("Generated tweets:", len(tweets))# Example Flume sync command (documentation purpose)print("Flume command: flume-ng agent -n TwitterAgent -f /usr/local/flume/conf/flume.conf")
