# %% [markdown]
# # Twitter Streaming with Apache Flume (Proposed Methodology)
# This notebook documents the secure configuration for collecting real-time tweets
# using the Twitter API and Apache Flume.

# %%
API_KEY = "YOUR_API_KEY"
API_SECRET = "YOUR_SECRET_KEY"
ACCESS_TOKEN = "YOUR_ACCESS_TOKEN"
ACCESS_TOKEN_SECRET = "YOUR_ACCESS_TOKEN_SECRET"

print("Credentials loaded (use environment variables in production).")

# %% [markdown]
# ## Flume Agent Command
# ```bash
# flume-ng agent -n TwitterAgent -f /usr/local/flume/conf/flume.conf
# ```
# HDFS tail command:
# ```bash
# hadoop fs -tail -f hdfs://192.168.1.165:9000/user/flume/ml/FlumeData.tmp
# ```
